# %%
import pandas as pd

# %%
df = pd.read_csv("output/byproduct_2_all_staffing.csv")
df.head()
# Out:
#    report_year                     index  \
# 0         2003  Amistad Academy District
# 1         2003  Amistad Academy District
# 2         2003  Amistad Academy District
# 3         2003  Amistad Academy District
# 4         2003  Amistad Academy District
#
#                                  Assignment Category  Educator Type  \
# 0  Administrators  Coordinators and Department Ch...      Certified
# 1  Counselors  Social Workers  and School Psychol...      Certified
# 2       General Education - Teachers and Instructors      Certified
# 3  General Education - Paraprofessional Instructi...  Non-Certified
# 4                      Library/Media - Support Staff  Non-Certified
#
#    FTE Count       City  OrganizationCode                 OrganizationType
# 0        1.8  NEW HAVEN         2790013.0  Public Charter School Districts
# 1        1.0  NEW HAVEN         2790013.0  Public Charter School Districts
# 2       14.9  NEW HAVEN         2790013.0  Public Charter School Districts
# ...

# %%
check_df = pd.pivot_table(
    df,
    index=["index","report_year"],
    values="FTE Count",
    columns="Assignment Category"
)

len(check_df[check_df["Counselors  Social Workers  and School Psychologists"].isnull()])
# Out:
# 428

# %%
len(check_df)
# Out:
# 3376

# %%
check_df[check_df["Counselors  Social Workers  and School Psychologists"].isnull()]
# Out:
# Assignment Category                                           Administrators  Coordinators and Department Chairs - District Central Office  \
# index                                            report_year
# Achievement First Hartford Academy Inc. District 2009                                                       NaN
# Amistad Academy District                         2002                                                       NaN
#                                                  2007                                                       NaN
#                                                  2008                                                       NaN
#                                                  2009                                                       NaN
# Andover School District                          2002                                                       NaN
# ...
